# %%
options(java.parameters = "-Xmx100000m")
# Load packages. 
library(loadeR)
library(transformeR)
library(loadeR.ECOMS)
library(visualizeR)
library(convertR)
library(drought4R)
library(downscaleR)

# Case Study:
# caseStudy={'Lake Arreskov','Denmark',55.16,10.31,'sub-daily','both';...
#   'Wupper Reservoir','Germany',51.1983,7.3011,'hourly or daily','both';...
#   'Burrishoole Catchment','Ireland',[53.8833 54.05],[-9.6833 -9.4833],'Daily','both';...
#   'Vansjo Catchment','Norway',[59.31 59.90],[10.63 11.25],'Daily','both';...
#   'Sau Reservoir','Spain',41.9702,2.3994,'Daily or sub-daily','both';...
#   'Mt. Bold Reservoir','Australia',[-35.15 -35.0167],[138.6667 138.8167],'6-hourly','both'};
####################################################################################################
## Example of Data Reference Sintax: How to build the directory structure and file naming         ##
## considering observations, reanalysis, seasonal forecast or climate change projections          ##
## SEE the proposal for the WATExR Archive Design in:                                             ## 
## https://docs.google.com/document/d/1yzNtw9W_z_ziPQ6GrnSgD9ov5O1swnohndDTAWOgpwc/edit           ##
####################################################################################################
#   Lake (lake_id): Is an identifier for the lake/case study.
#   institution (institute_id): Is an identifier for the institution that is responsible for the scientific aspects of the simulation.
#   LakeModelName (driving_lake_model_id): is an identifier of the driving lake model.
#     The name consists of an institute identifier and a lake model identifier. 
#     The two parts of the name are separated by a '-' (dash). Note that dashes in either of the two parts are allowed. 
#   ClimateModelName (driving_climate_model_id) is an identifier of the driving climate model.
#     The name consists of an institute identifier and a climate model identifier. 
#     The two parts of the name are separated by a '-' (dash). Note that dashes in either of the two parts are allowed.
#     For observations or reanalysis indicate the name of the data set as model identifier. 
#   ExperimentName (driving_experiment_name) is:
# Climate change projection: either "evaluation" or the value of the CMIP5 experiment_id of the data used ("historical", "rcp4.5", "rcp8.5", etc)
# Seasonal Forecasts: "seasonal"
# Observed data: "observations"
# Reanalysis: "reanalysis"
#   EnsembleMember (driving_model_ensemble_member) identifies the ensemble member of the global climate model, seasonal or climate change, experiment that produced the forcing data.
# Climate change: the format should be the same used in the CMIP5 (e.g. r1i1p1)
# Seasonal Forecasts: this element is defined by the member (e.g. member01 for the first member).
# Reanalysis: Set this element as member01 for reanalysis data.
#   Frequency (frequency) is the output frequency indicator: 6hr=6 hourly, day=daily, etc.
#   StartTime and EndTime indicate the time span of the file content. The format is YYYY[MM[DD[HH[MM]]]], i.e. the year is represented by 4 digits, 
# while the month, day, hour, and minutes are represented by exactly 2 digits, if they are present at all. In accordance with CMIP5, only those 
# digits have to be included that are necessary to indicate the file content. The two dates are separated by a dash. All time stamps refer to UTC.2.2 
##################################################################################################################################################################
# Out:
# Loading required package: rJava
# Loading required package: loadeR.java
# Java version 1.8x amd64 by Azul Systems, Inc. detected
# NetCDF Java Library v4.6.0-SNAPSHOT (23 Apr 2015) loaded and ready
# loadeR version 1.4.15 (2019-07-30) is loaded
# Please use 'citation("loadeR")' to cite this package.
# transformeR version 1.5.1 (2019-07-13) is loaded
# WARNING: Your current version of transformeR (v1.5.1) is not up-to-date
# Get the latest stable version (1.6.1) using <devtools::install_github('SantanderMetGroup/transformeR')>
# Please see 'citation("transformeR")' to cite this package.
# loadeR.ECOMS version 1.4.6 (2018-10-20) is loaded
# Please use 'citation("loadeR.ECOMS")' to cite this package.
# Warning message:
# “no DISPLAY variable so Tk is not available”visualizeR version 1.4.0 (2019-07-09) is loaded
# WARNING: Your current version of visualizeR (v1.4.0) is not up-to-date
# Get the latest stable version (1.5.0) using <devtools::install_github('SantanderMetGroup/visualizeR')>
# Please see 'citation("visualizeR")' to cite this package.
# Loading required package: udunits2
# udunits system database read from /opt/conda/lib/R/library/udunits2/share/udunits2.xml
# convertR version 0.1.2 (2018-06-28) is loaded
#   More information about the 'climate4R' ecosystem in: http://meteo.unican.es/climate4R
#
# Attaching package: ‘convertR’
#
# The following objects are masked from ‘package:loadeR’:
#
#     hurs2huss, huss2hurs
#
# drought4R version 0.2.0 (2019-04-24) is loaded
# downscaleR version 3.1.0 (2019-07-09) is loaded
# Please use 'citation("downscaleR")' to cite this package.

# %%
####### GENERAL SETTINGS THAT NEED TO BE DEFINED IN EACH CASE STUDY ---------------------------------

# Output path where the data will be saved (change to your local path).
dir.data <- './data/' 
dir.Rdata <- './Rdata/'

# %%
#Defining the geographical domain
lonLim <- c(8, 13) 
latLim <- c(57, 62)

# Define the period and the season
years <- 1979:2019
season <- 1:12 #Full year

# Location of the lake
lake <- list(x= 10.7438771059,  y= 59.4392814052 )
lakename <- 'Vansjo'

# %%
# Define the dataset 
## dataset <- "ECMWF_ERA-Interim-ESD"
dataset <- "http://meteo.unican.es/tds5/dodsC/interim/interim075_WATExR.ncml"

# Login in the TAP-UDG the climate4R libraries 
# More details about UDG in https://doi.org/10.1016/j.cliser.2017.07.001
loginUDG("WATExR", "1234567890")

# Check available variables in the dataset (EWEMBI)  
di <- dataInventory(dataset)
names(di)
# Out:
# [2019-11-13 11:28:21] Setting credentials...
# [2019-11-13 11:28:21] Success!
# Go to <http://www.meteo.unican.es/udg-tap/home> for details on your authorized groups and datasets
# [2019-11-13 11:28:21] Doing inventory ...
# [2019-11-13 11:28:23] Retrieving info for 'rsds' (15 vars remaining)
# [2019-11-13 11:28:24] Retrieving info for 'rlds' (14 vars remaining)
# [2019-11-13 11:28:24] Retrieving info for 'ssr' (13 vars remaining)
# [2019-11-13 11:28:24] Retrieving info for 'str' (12 vars remaining)
# [2019-11-13 11:28:24] Retrieving info for 'tsr' (11 vars remaining)
# [2019-11-13 11:28:24] Retrieving info for 'ttr' (10 vars remaining)
# [2019-11-13 11:28:24] Retrieving info for 'evaporation' (9 vars remaining)
# [2019-11-13 11:28:25] Retrieving info for 'pr' (8 vars remaining)
# [2019-11-13 11:28:25] Retrieving info for 'sst' (7 vars remaining)
# [2019-11-13 11:28:25] Retrieving info for 'ps' (6 vars remaining)
# [2019-11-13 11:28:25] Retrieving info for 'psl' (5 vars remaining)
# [2019-11-13 11:28:25] Retrieving info for 'tcc' (4 vars remaining)
# [2019-11-13 11:28:25] Retrieving info for 'uas' (3 vars remaining)
# [2019-11-13 11:28:25] Retrieving info for 'vas' (2 vars remaining)
# [2019-11-13 11:28:26] Retrieving info for 'tas' (1 vars remaining)
# [2019-11-13 11:28:26] Retrieving info for 'tdps' (0 vars remaining)
# [2019-11-13 11:28:26] Done.
#  [1] "rsds"        "rlds"        "ssr"         "str"         "tsr"
#  [6] "ttr"         "evaporation" "pr"          "sst"         "ps"
# [11] "psl"         "tcc"         "uas"         "vas"         "tas"
# [16] "tdps"

# %%
#Loading the observational (ewembi) data
dir.Rdata.obs <- "/home/jovyan/watexr/PROGNOS/notebooks/Rdata/PIK_Obs-EWEMBI_1_2_3_4_5_6_7_8_9_10_11_12_uas_vas_ps_tas_pr_rsds_rlds_hurs_cc.rda"

obs.data <- get(load(dir.Rdata.obs))
varnames.obs <- sapply(obs.data, function(x) getVarNames(x)) # to check the variables in the observational data.
print(varnames.obs)
# Out:
#    uas    vas     ps    tas     pr   rsds   rlds   hurs     cc
#  "uas"  "vas"   "ps"  "tas"   "pr" "rsds" "rlds" "hurs"   "cc"

# %%
variables <- c("uas", "vas", "ps", "tas", "pr", "rsds", "rlds")
# Define daily aggregation function for each variable selected. 
aggr.fun <- c("mean", "mean", "mean", "mean", "sum", "mean", "mean")
########## DATA LOADING AND TRANSFORMATION ----------------------------------------------------------
# Load reanalysis (ERA-Interim) with function loadGridData from package loadeR.
# Data is loaded in a loop (function lapply) to load all variables in a single code line.
# A list of grids is obtained, each slot in the list corresponds to a variable
data.prelim <- lapply(1:length(variables), function(x) loadGridData(dataset, var = variables[x], years = years, 
                                                                    lonLim = lonLim, latLim = latLim, season = season, 
                                                                    time = "DD", aggr.d = aggr.fun[x]))

# Deal with the special case of accumulated variables (get temporal intersection)
data.prelim <- intersectGrid(data.prelim, type = "temporal", which.return = 1:length(variables))
names(data.prelim) <- c("uas", "vas", "ps", "tas", "pr", "rsds", "rlds")

# Compute relative humidity from the mean temperature and the dew point with function tdps2hurs from package convertR
tdps <- loadGridData(dataset, var = "tdps", years = years, 
                     lonLim = lonLim, latLim = latLim, 
                     season = season,  time = "DD", aggr.d = "mean")
tdps <- intersectGrid(tdps, data.prelim$tas, which.return = 1)

hurs <- data.prelim$tas # Predefine the object
hurs$Data <- tdps2hurs(data.prelim$tas$Data, tdps$Data) # Assign the data matrix
# Define correctly the metadata of the object:
hurs$Variable$varName <- "hurs"
attr(hurs$Variable,"units") <- "%"
attr(hurs$Variable,"description") <- "2 metre relative humidity"
attr(hurs$Variable,"longname") <- "hurs"
# Include variables in data.prelim
data.prelim <- c(data.prelim, "hurs" = list(hurs))

# Compute wss
wss <- data.prelim$uas
wss$Data <- data.prelim$uas$Data^2 + data.prelim$vas$Data^2
# Define correctly the metadata of the object:
wss$Variable$varName <- "wss"
attr(wss$Variable,"units") <- "m s**-1"
attr(wss$Variable,"description") <- "Near-Surface Wind Speed"
attr(wss$Variable,"longname") <- "wss"
# Include variables in data.prelim
data.prelim <- c(data.prelim, "wss" = list(wss))

# Bilinear interpolation of the data to the location of the lake. See ?interpGrid for other methods.
data.interp <- lapply(data.prelim, function(x) interpGrid(x, new.coordinates = lake, 
                                                          method = "bilinear", 
                                                          bilin.method = "akima"))

# Convert pressure and temperature units to millibars and celsius with function udConvertGrid from package convertR.
data.interp$ps <- udConvertGrid(data.interp$ps, new.units = "millibars") #No need SWAT
data.interp$tas <- udConvertGrid(data.interp$tas, new.units = "celsius")
#data.interp$tasmax <- udConvertGrid(data.interp$tasmax, new.units = "celsius")
#data.interp$tasmin <- udConvertGrid(data.interp$tasmin, new.units = "celsius")

# Convert radiation units from J/m2/12hours to W/m2
data.interp$rsds$Data <- data.interp$rsds$Data/43200 
attr(data.interp$rsds$Variable,"units") <- "W.m-2"
data.interp$rlds$Data <- data.interp$rlds$Data/43200 
attr(data.interp$rlds$Variable,"units") <- "W.m-2"

#Convert relative humidity units to fractions with function udConvertGrid from package convertR.
#data.interp$hurs <- udConvertGrid(data.interp$hurs, new.units = "")

#Convert shortwave radiation units to MJ/(m2*day) with function udConvertGrid from package convertR.
#data.interp$rsds <- udConvertGrid(data.interp$rsds, new.units = "MJ m-2 day-1")
#data.interp$rlds <- udConvertGrid(data.interp$rlds, new.units = "MJ m-2 day-1")

# Compute cloud cover with function rad2cc
clt <- redim(rad2cc(rsds = data.interp$rsds, rlds = data.interp$rlds), drop = TRUE)
clt$Variable$varName <- "cc"

# Put all variables together
data <- c(data.interp, "cc" = list(clt))
# Out:
# [2019-11-13 11:28:26] Opening dataset...
# [2019-11-13 11:28:29] The dataset was successfuly opened
# [2019-11-13 11:28:29] Defining geo-location parameters
# [2019-11-13 11:28:29] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 6-hourly data
# [2019-11-13 11:28:30] Retrieving data subset ...
# [2019-11-13 11:32:46] Done
# [2019-11-13 11:32:46] Opening dataset...
# [2019-11-13 11:32:48] The dataset was successfuly opened
# [2019-11-13 11:32:48] Defining geo-location parameters
# [2019-11-13 11:32:48] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 6-hourly data
# [2019-11-13 11:32:49] Retrieving data subset ...
# [2019-11-13 11:37:34] Done
# [2019-11-13 11:37:34] Opening dataset...
# [2019-11-13 11:37:35] The dataset was successfuly opened
# [2019-11-13 11:37:35] Defining geo-location parameters
# [2019-11-13 11:37:35] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 6-hourly data
# [2019-11-13 11:37:37] Retrieving data subset ...
# [2019-11-13 11:42:53] Done
# [2019-11-13 11:42:53] Opening dataset...
# [2019-11-13 11:42:54] The dataset was successfuly opened
# [2019-11-13 11:42:54] Defining geo-location parameters
# [2019-11-13 11:42:54] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 6-hourly data
# [2019-11-13 11:42:55] Retrieving data subset ...
# [2019-11-13 11:47:48] Done
# [2019-11-13 11:47:48] Opening dataset...
# [2019-11-13 11:47:49] The dataset was successfuly opened
# [2019-11-13 11:47:49] Defining geo-location parameters
# [2019-11-13 11:47:49] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 12-hourly data
# [2019-11-13 11:47:50] Retrieving data subset ...
# [2019-11-13 11:50:08] Done
# [2019-11-13 11:50:08] Opening dataset...
# [2019-11-13 11:50:09] The dataset was successfuly opened
# [2019-11-13 11:50:09] Defining geo-location parameters
# [2019-11-13 11:50:09] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 12-hourly data
# [2019-11-13 11:50:10] Retrieving data subset ...
# [2019-11-13 11:53:08] Done
# [2019-11-13 11:53:08] Opening dataset...
# [2019-11-13 11:53:10] The dataset was successfuly opened
# [2019-11-13 11:53:10] Defining geo-location parameters
# [2019-11-13 11:53:10] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 12-hourly data
# [2019-11-13 11:53:10] Retrieving data subset ...
# [2019-11-13 11:55:46] Done
# [2019-11-13 11:55:47] Opening dataset...
# [2019-11-13 11:55:48] The dataset was successfuly opened
# [2019-11-13 11:55:48] Defining geo-location parameters
# [2019-11-13 11:55:48] Defining time selection parameters
# NOTE: Daily aggregation will be computed from 6-hourly data
# [2019-11-13 11:55:49] Retrieving data subset ...
# [2019-11-13 12:01:49] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:01:49] Performing bilinear interpolation... may take a while
# [2019-11-13 12:02:00] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:02:00] Performing bilinear interpolation... may take a while
# [2019-11-13 12:02:11] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:02:11] Performing bilinear interpolation... may take a while
# [2019-11-13 12:02:23] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:02:23] Performing bilinear interpolation... may take a while
# [2019-11-13 12:02:34] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:02:34] Performing bilinear interpolation... may take a while
# [2019-11-13 12:02:45] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:02:46] Performing bilinear interpolation... may take a while
# [2019-11-13 12:02:56] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:02:56] Performing bilinear interpolation... may take a while
# [2019-11-13 12:03:07] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:03:07] Performing bilinear interpolation... may take a while
# [2019-11-13 12:03:19] Done
# NOTE: New coordinates are irregular, bilin.method = 'fields'
# [2019-11-13 12:03:19] Performing bilinear interpolation... may take a while
# [2019-11-13 12:03:30] Done
# [2019-11-13 12:03:30] Estimating cloud cover ...
# [2019-11-13 12:03:31] Done.

# %%
install.packages("rlist")
library("rlist")
list.save(data, "erainterim_noconvert.rds")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
# Check variable consistency
if (!all(names(obs.data) %in% names(data))) stop("variables in obs.data and data (seasonal forecast) do not match.")

# #order variables
data <- data[match(names(obs.data), names(data))]
varnames <- names(data)

##### BIAS CORRECTION -----------------------------------------------------------------------
# Subset observational data to the same dates as forecast data
obs.data <- lapply(1:length(obs.data), function(x)  {intersectGrid(obs.data[[x]], data[[x]], type = "temporal", which.return = 1)})
data <- lapply(1:length(obs.data), function(x)  {intersectGrid(obs.data[[x]], data[[x]], type = "temporal", which.return = 2)})
names(obs.data) <- varnames
names(data) <- varnames

# Collect some common metadata (e.g. from variable uas)
dates <- data[[1]]$Dates
xycoords <- getCoordinates(data[[1]])

# Bias correction with leave-one-year-out ("loo") cross-validation
# type ?biasCorrection in R for more info about the parameter settings for bias correction.
data.bc.cross <- lapply(1:length(data), function(x)  {
  precip <- FALSE
  #if (names(data)[x] == "pr") precip <- TRUE
  biasCorrection(y = obs.data[[x]], x = data[[x]], 
                 method = "eqm", cross.val = "loo",
                 precipitation = precip,
                 wet.threshold = 1,
                 window = c(90, 31),
                 join.members = TRUE)
}) 
names(data.bc.cross) <- varnames
# Bias correction without cross-validation
data.bc <- lapply(1:length(data), function(v)  {
  pre <- FALSE
  print(names(data)[v])
  #if (names(data)[v] == "pr") pre <- TRUE
  biasCorrection(y = obs.data[[v]], x = data[[v]], 
                 method = "eqm",
                 precipitation = pre,
                 wet.threshold = 1,
                 window = c(90, 31),
                 join.members = TRUE)
}) 
names(data.bc) <- varnames


# save Rdata (*.rda file)
save(data, file = paste0(dir.Rdata, "interim075_WATExR_", paste0(season, collapse = "_"), "_", paste0(names(data), collapse = "_"), "_raw.rda"))
save(data.bc.cross, file = paste0(dir.Rdata, "interim075_WATExR_", paste0(season, collapse = "_"), "_", paste0(names(data), collapse = "_"), "_BCcross.rda"))
save(data.bc, file = paste0(dir.Rdata, "interim075_WATExR_", paste0(season, collapse = "_"), "_", paste0(names(data), collapse = "_"), "_BC.rda"))

list.save(data, "erainterim_bias_raw_no_precip.rds")
list.save(data.bc.cross, "erainterim_bias_bc_cross_no_precip.rds")
list.save(data.bc, "erainterim_bias_bc_no_precip.rds")




# ########## BUILD FINAL DATA --------------------------------------------------------------

# datatoexport <- data.bc

# # extract the data arrays of all variables from the list
# data <- lapply(datatoexport, function(x) x[["Data"]])

# # Remove unwanted variables from output
# data["rsds"] <- NULL 
# data["rlds"] <- NULL
# # Build data frame
# yymmdd <- as.Date(dates$start)
# hhmmss <- format(as.POSIXlt(dates$start), format = "%H:%M:%S") 
# df <- data.frame(c(list("dates1" = yymmdd, "dates2" = hhmmss)), data)


# ########### EXPORT DATA ACCORDING TO THE WATExR ARCHIVE DESIGN -----------------------------
# ## SEE the proposal for the WATExR Archive Design in:                                            
# ## https://docs.google.com/document/d/1yzNtw9W_z_ziPQ6GrnSgD9ov5O1swnohndDTAWOgpwc/edit

# # Define metadata to generate the file name
# institution <- "UC"
# lake_id <- lakename
# ClimateModelName <- "ERA-Interim"
# ExperimentName <- "reanalysis"
# member <- "member01"
# freq <- "day"

# # Create directory and save file
# startTime <- format(as.POSIXlt(yymmdd[1]), format = "%Y%m%d")
# endTime <- format(tail(as.POSIXlt(yymmdd), n = 1), format = "%Y%m%d")
# dirName <- paste0(dir.data, lake_id, "/CLIMATE/", lake_id, "_", institution, "_", ClimateModelName, "_", ExperimentName, "_", member, "_", freq, "_", startTime, "-", endTime, "/", sep = "", collapse = NULL)
# dir.create(dirName, showWarnings = TRUE, recursive = TRUE, mode = "0777")
# write.table(df, paste0(dirName,"meteo_file.dat", sep = "", collapse = NULL), sep = "\t", row.names = FALSE, col.names = FALSE, quote = FALSE)
# Out:
# Validation 1, 37 remaining
# [2019-11-13 12:03:39] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:03:43] Number of windows considered: 11...
# [2019-11-13 12:03:43] Bias-correcting 1 members separately...
# [2019-11-13 12:03:43] Done.
# Validation 2, 36 remaining
# [2019-11-13 12:03:45] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:03:49] Number of windows considered: 11...
# [2019-11-13 12:03:49] Bias-correcting 1 members separately...
# [2019-11-13 12:03:49] Done.
# Validation 3, 35 remaining
# [2019-11-13 12:03:51] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:03:55] Number of windows considered: 11...
# [2019-11-13 12:03:55] Bias-correcting 1 members separately...
# [2019-11-13 12:03:55] Done.
# Validation 4, 34 remaining
# [2019-11-13 12:03:56] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:00] Number of windows considered: 11...
# [2019-11-13 12:04:00] Bias-correcting 1 members separately...
# [2019-11-13 12:04:00] Done.
# Validation 5, 33 remaining
# [2019-11-13 12:04:02] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:06] Number of windows considered: 11...
# [2019-11-13 12:04:06] Bias-correcting 1 members separately...
# [2019-11-13 12:04:06] Done.
# Validation 6, 32 remaining
# [2019-11-13 12:04:07] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:11] Number of windows considered: 11...
# [2019-11-13 12:04:11] Bias-correcting 1 members separately...
# [2019-11-13 12:04:11] Done.
# Validation 7, 31 remaining
# [2019-11-13 12:04:13] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:17] Number of windows considered: 11...
# [2019-11-13 12:04:17] Bias-correcting 1 members separately...
# [2019-11-13 12:04:17] Done.
# Validation 8, 30 remaining
# [2019-11-13 12:04:19] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:23] Number of windows considered: 11...
# [2019-11-13 12:04:23] Bias-correcting 1 members separately...
# [2019-11-13 12:04:23] Done.
# Validation 9, 29 remaining
# [2019-11-13 12:04:24] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:28] Number of windows considered: 11...
# [2019-11-13 12:04:28] Bias-correcting 1 members separately...
# [2019-11-13 12:04:28] Done.
# Validation 10, 28 remaining
# [2019-11-13 12:04:29] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:33] Number of windows considered: 11...
# [2019-11-13 12:04:33] Bias-correcting 1 members separately...
# [2019-11-13 12:04:34] Done.
# Validation 11, 27 remaining
# [2019-11-13 12:04:35] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:39] Number of windows considered: 11...
# [2019-11-13 12:04:39] Bias-correcting 1 members separately...
# [2019-11-13 12:04:39] Done.
# Validation 12, 26 remaining
# [2019-11-13 12:04:41] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:45] Number of windows considered: 11...
# [2019-11-13 12:04:45] Bias-correcting 1 members separately...
# [2019-11-13 12:04:45] Done.
# Validation 13, 25 remaining
# [2019-11-13 12:04:46] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:50] Number of windows considered: 11...
# [2019-11-13 12:04:50] Bias-correcting 1 members separately...
# [2019-11-13 12:04:50] Done.
# Validation 14, 24 remaining
# [2019-11-13 12:04:52] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:04:56] Number of windows considered: 11...
# [2019-11-13 12:04:56] Bias-correcting 1 members separately...
# [2019-11-13 12:04:56] Done.
# Validation 15, 23 remaining
# [2019-11-13 12:04:57] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:01] Number of windows considered: 11...
# [2019-11-13 12:05:01] Bias-correcting 1 members separately...
# [2019-11-13 12:05:01] Done.
# Validation 16, 22 remaining
# [2019-11-13 12:05:02] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:06] Number of windows considered: 11...
# [2019-11-13 12:05:06] Bias-correcting 1 members separately...
# [2019-11-13 12:05:07] Done.
# Validation 17, 21 remaining
# [2019-11-13 12:05:08] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:12] Number of windows considered: 11...
# [2019-11-13 12:05:12] Bias-correcting 1 members separately...
# [2019-11-13 12:05:12] Done.
# Validation 18, 20 remaining
# [2019-11-13 12:05:14] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:18] Number of windows considered: 11...
# [2019-11-13 12:05:18] Bias-correcting 1 members separately...
# [2019-11-13 12:05:18] Done.
# Validation 19, 19 remaining
# [2019-11-13 12:05:19] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:23] Number of windows considered: 11...
# [2019-11-13 12:05:23] Bias-correcting 1 members separately...
# [2019-11-13 12:05:23] Done.
# Validation 20, 18 remaining
# [2019-11-13 12:05:25] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:29] Number of windows considered: 11...
# [2019-11-13 12:05:29] Bias-correcting 1 members separately...
# [2019-11-13 12:05:29] Done.
# Validation 21, 17 remaining
# [2019-11-13 12:05:30] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:34] Number of windows considered: 11...
# [2019-11-13 12:05:34] Bias-correcting 1 members separately...
# [2019-11-13 12:05:35] Done.
# Validation 22, 16 remaining
# [2019-11-13 12:05:36] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:40] Number of windows considered: 11...
# [2019-11-13 12:05:40] Bias-correcting 1 members separately...
# [2019-11-13 12:05:40] Done.
# Validation 23, 15 remaining
# [2019-11-13 12:05:42] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:46] Number of windows considered: 11...
# [2019-11-13 12:05:46] Bias-correcting 1 members separately...
# [2019-11-13 12:05:46] Done.
# Validation 24, 14 remaining
# [2019-11-13 12:05:47] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:51] Number of windows considered: 11...
# [2019-11-13 12:05:51] Bias-correcting 1 members separately...
# [2019-11-13 12:05:51] Done.
# Validation 25, 13 remaining
# [2019-11-13 12:05:53] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:05:57] Number of windows considered: 11...
# [2019-11-13 12:05:57] Bias-correcting 1 members separately...
# [2019-11-13 12:05:57] Done.
# Validation 26, 12 remaining
# [2019-11-13 12:05:58] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:02] Number of windows considered: 11...
# [2019-11-13 12:06:02] Bias-correcting 1 members separately...
# [2019-11-13 12:06:02] Done.
# Validation 27, 11 remaining
# [2019-11-13 12:06:04] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:08] Number of windows considered: 11...
# [2019-11-13 12:06:08] Bias-correcting 1 members separately...
# [2019-11-13 12:06:08] Done.
# Validation 28, 10 remaining
# [2019-11-13 12:06:09] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:14] Number of windows considered: 11...
# [2019-11-13 12:06:14] Bias-correcting 1 members separately...
# [2019-11-13 12:06:14] Done.
# Validation 29, 9 remaining
# [2019-11-13 12:06:15] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:19] Number of windows considered: 11...
# [2019-11-13 12:06:19] Bias-correcting 1 members separately...
# [2019-11-13 12:06:20] Done.
# Validation 30, 8 remaining
# [2019-11-13 12:06:21] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:25] Number of windows considered: 11...
# [2019-11-13 12:06:25] Bias-correcting 1 members separately...
# [2019-11-13 12:06:26] Done.
# Validation 31, 7 remaining
# [2019-11-13 12:06:27] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:31] Number of windows considered: 11...
# [2019-11-13 12:06:31] Bias-correcting 1 members separately...
# [2019-11-13 12:06:31] Done.
# Validation 32, 6 remaining
# [2019-11-13 12:06:32] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:36] Number of windows considered: 11...
# [2019-11-13 12:06:36] Bias-correcting 1 members separately...
# [2019-11-13 12:06:36] Done.
# Validation 33, 5 remaining
# [2019-11-13 12:06:38] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:41] Number of windows considered: 11...
# [2019-11-13 12:06:41] Bias-correcting 1 members separately...
# [2019-11-13 12:06:42] Done.
# Validation 34, 4 remaining
# [2019-11-13 12:06:43] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:47] Number of windows considered: 11...
# [2019-11-13 12:06:47] Bias-correcting 1 members separately...
# [2019-11-13 12:06:47] Done.
# Validation 35, 3 remaining
# [2019-11-13 12:06:48] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:53] Number of windows considered: 11...
# [2019-11-13 12:06:53] Bias-correcting 1 members separately...
# [2019-11-13 12:06:53] Done.
# Validation 36, 2 remaining
# [2019-11-13 12:06:54] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:06:58] Number of windows considered: 11...
# [2019-11-13 12:06:58] Bias-correcting 1 members separately...
# [2019-11-13 12:06:58] Done.
# Validation 37, 1 remaining
# [2019-11-13 12:07:00] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:04] Number of windows considered: 11...
# [2019-11-13 12:07:04] Bias-correcting 1 members separately...
# [2019-11-13 12:07:04] Done.
# Validation 38, 0 remaining
# [2019-11-13 12:07:05] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:09] Number of windows considered: 11...
# [2019-11-13 12:07:09] Bias-correcting 1 members separately...
# [2019-11-13 12:07:10] Done.
# Validation 1, 37 remaining
# [2019-11-13 12:07:11] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:16] Number of windows considered: 11...
# [2019-11-13 12:07:16] Bias-correcting 1 members separately...
# [2019-11-13 12:07:16] Done.
# Validation 2, 36 remaining
# [2019-11-13 12:07:17] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:21] Number of windows considered: 11...
# [2019-11-13 12:07:21] Bias-correcting 1 members separately...
# [2019-11-13 12:07:21] Done.
# Validation 3, 35 remaining
# [2019-11-13 12:07:22] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:26] Number of windows considered: 11...
# [2019-11-13 12:07:26] Bias-correcting 1 members separately...
# [2019-11-13 12:07:27] Done.
# Validation 4, 34 remaining
# [2019-11-13 12:07:28] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:32] Number of windows considered: 11...
# [2019-11-13 12:07:32] Bias-correcting 1 members separately...
# [2019-11-13 12:07:32] Done.
# Validation 5, 33 remaining
# [2019-11-13 12:07:33] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:37] Number of windows considered: 11...
# [2019-11-13 12:07:37] Bias-correcting 1 members separately...
# [2019-11-13 12:07:38] Done.
# Validation 6, 32 remaining
# [2019-11-13 12:07:39] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:43] Number of windows considered: 11...
# [2019-11-13 12:07:43] Bias-correcting 1 members separately...
# [2019-11-13 12:07:43] Done.
# Validation 7, 31 remaining
# [2019-11-13 12:07:44] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:48] Number of windows considered: 11...
# [2019-11-13 12:07:48] Bias-correcting 1 members separately...
# [2019-11-13 12:07:49] Done.
# Validation 8, 30 remaining
# [2019-11-13 12:07:50] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:07:54] Number of windows considered: 11...
# [2019-11-13 12:07:54] Bias-correcting 1 members separately...
# [2019-11-13 12:07:54] Done.
# Validation 9, 29 remaining
# [2019-11-13 12:07:56] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:00] Number of windows considered: 11...
# [2019-11-13 12:08:00] Bias-correcting 1 members separately...
# [2019-11-13 12:08:00] Done.
# Validation 10, 28 remaining
# [2019-11-13 12:08:02] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:06] Number of windows considered: 11...
# [2019-11-13 12:08:06] Bias-correcting 1 members separately...
# [2019-11-13 12:08:06] Done.
# Validation 11, 27 remaining
# [2019-11-13 12:08:07] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:11] Number of windows considered: 11...
# [2019-11-13 12:08:11] Bias-correcting 1 members separately...
# [2019-11-13 12:08:11] Done.
# Validation 12, 26 remaining
# [2019-11-13 12:08:13] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:17] Number of windows considered: 11...
# [2019-11-13 12:08:17] Bias-correcting 1 members separately...
# [2019-11-13 12:08:17] Done.
# Validation 13, 25 remaining
# [2019-11-13 12:08:18] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:22] Number of windows considered: 11...
# [2019-11-13 12:08:22] Bias-correcting 1 members separately...
# [2019-11-13 12:08:23] Done.
# Validation 14, 24 remaining
# [2019-11-13 12:08:24] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:28] Number of windows considered: 11...
# [2019-11-13 12:08:28] Bias-correcting 1 members separately...
# [2019-11-13 12:08:28] Done.
# Validation 15, 23 remaining
# [2019-11-13 12:08:30] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:33] Number of windows considered: 11...
# [2019-11-13 12:08:33] Bias-correcting 1 members separately...
# [2019-11-13 12:08:34] Done.
# Validation 16, 22 remaining
# [2019-11-13 12:08:35] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:39] Number of windows considered: 11...
# [2019-11-13 12:08:39] Bias-correcting 1 members separately...
# [2019-11-13 12:08:39] Done.
# Validation 17, 21 remaining
# [2019-11-13 12:08:41] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:45] Number of windows considered: 11...
# [2019-11-13 12:08:45] Bias-correcting 1 members separately...
# [2019-11-13 12:08:45] Done.
# Validation 18, 20 remaining
# [2019-11-13 12:08:47] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:51] Number of windows considered: 11...
# [2019-11-13 12:08:51] Bias-correcting 1 members separately...
# [2019-11-13 12:08:51] Done.
# Validation 19, 19 remaining
# [2019-11-13 12:08:52] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:08:56] Number of windows considered: 11...
# [2019-11-13 12:08:56] Bias-correcting 1 members separately...
# [2019-11-13 12:08:56] Done.
# Validation 20, 18 remaining
# [2019-11-13 12:08:58] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:02] Number of windows considered: 11...
# [2019-11-13 12:09:02] Bias-correcting 1 members separately...
# [2019-11-13 12:09:02] Done.
# Validation 21, 17 remaining
# [2019-11-13 12:09:03] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:07] Number of windows considered: 11...
# [2019-11-13 12:09:07] Bias-correcting 1 members separately...
# [2019-11-13 12:09:07] Done.
# Validation 22, 16 remaining
# [2019-11-13 12:09:09] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:13] Number of windows considered: 11...
# [2019-11-13 12:09:13] Bias-correcting 1 members separately...
# [2019-11-13 12:09:13] Done.
# Validation 23, 15 remaining
# [2019-11-13 12:09:14] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:18] Number of windows considered: 11...
# [2019-11-13 12:09:18] Bias-correcting 1 members separately...
# [2019-11-13 12:09:19] Done.
# Validation 24, 14 remaining
# [2019-11-13 12:09:20] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:24] Number of windows considered: 11...
# [2019-11-13 12:09:24] Bias-correcting 1 members separately...
# [2019-11-13 12:09:24] Done.
# Validation 25, 13 remaining
# [2019-11-13 12:09:26] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:30] Number of windows considered: 11...
# [2019-11-13 12:09:30] Bias-correcting 1 members separately...
# [2019-11-13 12:09:30] Done.
# Validation 26, 12 remaining
# [2019-11-13 12:09:31] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:36] Number of windows considered: 11...
# [2019-11-13 12:09:36] Bias-correcting 1 members separately...
# [2019-11-13 12:09:36] Done.
# Validation 27, 11 remaining
# [2019-11-13 12:09:37] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:41] Number of windows considered: 11...
# [2019-11-13 12:09:41] Bias-correcting 1 members separately...
# [2019-11-13 12:09:41] Done.
# Validation 28, 10 remaining
# [2019-11-13 12:09:42] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:46] Number of windows considered: 11...
# [2019-11-13 12:09:46] Bias-correcting 1 members separately...
# [2019-11-13 12:09:46] Done.
# Validation 29, 9 remaining
# [2019-11-13 12:09:48] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:52] Number of windows considered: 11...
# [2019-11-13 12:09:52] Bias-correcting 1 members separately...
# [2019-11-13 12:09:52] Done.
# Validation 30, 8 remaining
# [2019-11-13 12:09:53] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:09:57] Number of windows considered: 11...
# [2019-11-13 12:09:57] Bias-correcting 1 members separately...
# [2019-11-13 12:09:57] Done.
# Validation 31, 7 remaining
# [2019-11-13 12:09:59] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:03] Number of windows considered: 11...
# [2019-11-13 12:10:03] Bias-correcting 1 members separately...
# [2019-11-13 12:10:03] Done.
# Validation 32, 6 remaining
# [2019-11-13 12:10:04] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:08] Number of windows considered: 11...
# [2019-11-13 12:10:08] Bias-correcting 1 members separately...
# [2019-11-13 12:10:09] Done.
# Validation 33, 5 remaining
# [2019-11-13 12:10:10] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:14] Number of windows considered: 11...
# [2019-11-13 12:10:14] Bias-correcting 1 members separately...
# [2019-11-13 12:10:15] Done.
# Validation 34, 4 remaining
# [2019-11-13 12:10:16] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:20] Number of windows considered: 11...
# [2019-11-13 12:10:20] Bias-correcting 1 members separately...
# [2019-11-13 12:10:20] Done.
# Validation 35, 3 remaining
# [2019-11-13 12:10:21] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:25] Number of windows considered: 11...
# [2019-11-13 12:10:25] Bias-correcting 1 members separately...
# [2019-11-13 12:10:26] Done.
# Validation 36, 2 remaining
# [2019-11-13 12:10:27] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:31] Number of windows considered: 11...
# [2019-11-13 12:10:31] Bias-correcting 1 members separately...
# [2019-11-13 12:10:31] Done.
# Validation 37, 1 remaining
# [2019-11-13 12:10:32] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:36] Number of windows considered: 11...
# [2019-11-13 12:10:36] Bias-correcting 1 members separately...
# [2019-11-13 12:10:37] Done.
# Validation 38, 0 remaining
# [2019-11-13 12:10:38] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:42] Number of windows considered: 11...
# [2019-11-13 12:10:42] Bias-correcting 1 members separately...
# [2019-11-13 12:10:42] Done.
# Validation 1, 37 remaining
# [2019-11-13 12:10:43] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:48] Number of windows considered: 11...
# [2019-11-13 12:10:48] Bias-correcting 1 members separately...
# [2019-11-13 12:10:48] Done.
# Validation 2, 36 remaining
# [2019-11-13 12:10:49] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:53] Number of windows considered: 11...
# [2019-11-13 12:10:53] Bias-correcting 1 members separately...
# [2019-11-13 12:10:53] Done.
# Validation 3, 35 remaining
# [2019-11-13 12:10:55] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:10:59] Number of windows considered: 11...
# [2019-11-13 12:10:59] Bias-correcting 1 members separately...
# [2019-11-13 12:10:59] Done.
# Validation 4, 34 remaining
# [2019-11-13 12:11:01] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:05] Number of windows considered: 11...
# [2019-11-13 12:11:05] Bias-correcting 1 members separately...
# [2019-11-13 12:11:05] Done.
# Validation 5, 33 remaining
# [2019-11-13 12:11:07] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:11] Number of windows considered: 11...
# [2019-11-13 12:11:11] Bias-correcting 1 members separately...
# [2019-11-13 12:11:11] Done.
# Validation 6, 32 remaining
# [2019-11-13 12:11:12] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:16] Number of windows considered: 11...
# [2019-11-13 12:11:16] Bias-correcting 1 members separately...
# [2019-11-13 12:11:16] Done.
# Validation 7, 31 remaining
# [2019-11-13 12:11:18] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:22] Number of windows considered: 11...
# [2019-11-13 12:11:22] Bias-correcting 1 members separately...
# [2019-11-13 12:11:22] Done.
# Validation 8, 30 remaining
# [2019-11-13 12:11:23] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:27] Number of windows considered: 11...
# [2019-11-13 12:11:27] Bias-correcting 1 members separately...
# [2019-11-13 12:11:28] Done.
# Validation 9, 29 remaining
# [2019-11-13 12:11:29] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:33] Number of windows considered: 11...
# [2019-11-13 12:11:33] Bias-correcting 1 members separately...
# [2019-11-13 12:11:33] Done.
# Validation 10, 28 remaining
# [2019-11-13 12:11:34] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:38] Number of windows considered: 11...
# [2019-11-13 12:11:38] Bias-correcting 1 members separately...
# [2019-11-13 12:11:39] Done.
# Validation 11, 27 remaining
# [2019-11-13 12:11:40] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:44] Number of windows considered: 11...
# [2019-11-13 12:11:44] Bias-correcting 1 members separately...
# [2019-11-13 12:11:44] Done.
# Validation 12, 26 remaining
# [2019-11-13 12:11:46] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:50] Number of windows considered: 11...
# [2019-11-13 12:11:50] Bias-correcting 1 members separately...
# [2019-11-13 12:11:50] Done.
# Validation 13, 25 remaining
# [2019-11-13 12:11:51] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:11:55] Number of windows considered: 11...
# [2019-11-13 12:11:55] Bias-correcting 1 members separately...
# [2019-11-13 12:11:56] Done.
# Validation 14, 24 remaining
# [2019-11-13 12:11:57] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:01] Number of windows considered: 11...
# [2019-11-13 12:12:01] Bias-correcting 1 members separately...
# [2019-11-13 12:12:01] Done.
# Validation 15, 23 remaining
# [2019-11-13 12:12:02] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:06] Number of windows considered: 11...
# [2019-11-13 12:12:06] Bias-correcting 1 members separately...
# [2019-11-13 12:12:06] Done.
# Validation 16, 22 remaining
# [2019-11-13 12:12:08] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:12] Number of windows considered: 11...
# [2019-11-13 12:12:12] Bias-correcting 1 members separately...
# [2019-11-13 12:12:12] Done.
# Validation 17, 21 remaining
# [2019-11-13 12:12:13] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:17] Number of windows considered: 11...
# [2019-11-13 12:12:17] Bias-correcting 1 members separately...
# [2019-11-13 12:12:18] Done.
# Validation 18, 20 remaining
# [2019-11-13 12:12:19] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:23] Number of windows considered: 11...
# [2019-11-13 12:12:23] Bias-correcting 1 members separately...
# [2019-11-13 12:12:23] Done.
# Validation 19, 19 remaining
# [2019-11-13 12:12:25] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:29] Number of windows considered: 11...
# [2019-11-13 12:12:29] Bias-correcting 1 members separately...
# [2019-11-13 12:12:29] Done.
# Validation 20, 18 remaining
# [2019-11-13 12:12:30] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:34] Number of windows considered: 11...
# [2019-11-13 12:12:34] Bias-correcting 1 members separately...
# [2019-11-13 12:12:34] Done.
# Validation 21, 17 remaining
# [2019-11-13 12:12:35] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:39] Number of windows considered: 11...
# [2019-11-13 12:12:39] Bias-correcting 1 members separately...
# [2019-11-13 12:12:40] Done.
# Validation 22, 16 remaining
# [2019-11-13 12:12:41] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:45] Number of windows considered: 11...
# [2019-11-13 12:12:45] Bias-correcting 1 members separately...
# [2019-11-13 12:12:45] Done.
# Validation 23, 15 remaining
# [2019-11-13 12:12:47] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:51] Number of windows considered: 11...
# [2019-11-13 12:12:51] Bias-correcting 1 members separately...
# [2019-11-13 12:12:51] Done.
# Validation 24, 14 remaining
# [2019-11-13 12:12:52] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:12:56] Number of windows considered: 11...
# [2019-11-13 12:12:56] Bias-correcting 1 members separately...
# [2019-11-13 12:12:56] Done.
# Validation 25, 13 remaining
# [2019-11-13 12:12:57] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:01] Number of windows considered: 11...
# [2019-11-13 12:13:01] Bias-correcting 1 members separately...
# [2019-11-13 12:13:02] Done.
# Validation 26, 12 remaining
# [2019-11-13 12:13:03] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:07] Number of windows considered: 11...
# [2019-11-13 12:13:07] Bias-correcting 1 members separately...
# [2019-11-13 12:13:07] Done.
# Validation 27, 11 remaining
# [2019-11-13 12:13:09] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:12] Number of windows considered: 11...
# [2019-11-13 12:13:12] Bias-correcting 1 members separately...
# [2019-11-13 12:13:13] Done.
# Validation 28, 10 remaining
# [2019-11-13 12:13:14] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:18] Number of windows considered: 11...
# [2019-11-13 12:13:18] Bias-correcting 1 members separately...
# [2019-11-13 12:13:18] Done.
# Validation 29, 9 remaining
# [2019-11-13 12:13:20] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:24] Number of windows considered: 11...
# [2019-11-13 12:13:24] Bias-correcting 1 members separately...
# [2019-11-13 12:13:24] Done.
# Validation 30, 8 remaining
# [2019-11-13 12:13:25] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:29] Number of windows considered: 11...
# [2019-11-13 12:13:29] Bias-correcting 1 members separately...
# [2019-11-13 12:13:29] Done.
# Validation 31, 7 remaining
# [2019-11-13 12:13:31] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:35] Number of windows considered: 11...
# [2019-11-13 12:13:35] Bias-correcting 1 members separately...
# [2019-11-13 12:13:35] Done.
# Validation 32, 6 remaining
# [2019-11-13 12:13:37] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:13:41] Number of windows considered: 11...
# [2019-11-13 12:13:41] Bias-correcting 1 members separately...
# [2019-11-13 12:13:41] Done.
# Validation 33, 5 remaining
# ...
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:05] Number of windows considered: 11...
# [2019-11-13 12:33:05] Bias-correcting 1 members separately...
# [2019-11-13 12:33:05] Done.
# Validation 12, 26 remaining
# [2019-11-13 12:33:07] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:11] Number of windows considered: 11...
# [2019-11-13 12:33:11] Bias-correcting 1 members separately...
# [2019-11-13 12:33:11] Done.
# Validation 13, 25 remaining
# [2019-11-13 12:33:12] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:16] Number of windows considered: 11...
# [2019-11-13 12:33:16] Bias-correcting 1 members separately...
# [2019-11-13 12:33:16] Done.
# Validation 14, 24 remaining
# [2019-11-13 12:33:17] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:21] Number of windows considered: 11...
# [2019-11-13 12:33:21] Bias-correcting 1 members separately...
# [2019-11-13 12:33:22] Done.
# Validation 15, 23 remaining
# [2019-11-13 12:33:23] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:27] Number of windows considered: 11...
# [2019-11-13 12:33:27] Bias-correcting 1 members separately...
# [2019-11-13 12:33:27] Done.
# Validation 16, 22 remaining
# [2019-11-13 12:33:29] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:33] Number of windows considered: 11...
# [2019-11-13 12:33:33] Bias-correcting 1 members separately...
# [2019-11-13 12:33:33] Done.
# Validation 17, 21 remaining
# [2019-11-13 12:33:34] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:39] Number of windows considered: 11...
# [2019-11-13 12:33:39] Bias-correcting 1 members separately...
# [2019-11-13 12:33:39] Done.
# Validation 18, 20 remaining
# [2019-11-13 12:33:40] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:44] Number of windows considered: 11...
# [2019-11-13 12:33:44] Bias-correcting 1 members separately...
# [2019-11-13 12:33:44] Done.
# Validation 19, 19 remaining
# [2019-11-13 12:33:46] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:50] Number of windows considered: 11...
# [2019-11-13 12:33:50] Bias-correcting 1 members separately...
# [2019-11-13 12:33:50] Done.
# Validation 20, 18 remaining
# [2019-11-13 12:33:52] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:33:56] Number of windows considered: 11...
# [2019-11-13 12:33:56] Bias-correcting 1 members separately...
# [2019-11-13 12:33:57] Done.
# Validation 21, 17 remaining
# [2019-11-13 12:33:58] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:02] Number of windows considered: 11...
# [2019-11-13 12:34:02] Bias-correcting 1 members separately...
# [2019-11-13 12:34:02] Done.
# Validation 22, 16 remaining
# [2019-11-13 12:34:03] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:07] Number of windows considered: 11...
# [2019-11-13 12:34:07] Bias-correcting 1 members separately...
# [2019-11-13 12:34:08] Done.
# Validation 23, 15 remaining
# [2019-11-13 12:34:09] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:13] Number of windows considered: 11...
# [2019-11-13 12:34:13] Bias-correcting 1 members separately...
# [2019-11-13 12:34:13] Done.
# Validation 24, 14 remaining
# [2019-11-13 12:34:14] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:18] Number of windows considered: 11...
# [2019-11-13 12:34:18] Bias-correcting 1 members separately...
# [2019-11-13 12:34:19] Done.
# Validation 25, 13 remaining
# [2019-11-13 12:34:20] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:24] Number of windows considered: 11...
# [2019-11-13 12:34:24] Bias-correcting 1 members separately...
# [2019-11-13 12:34:24] Done.
# Validation 26, 12 remaining
# [2019-11-13 12:34:25] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:30] Number of windows considered: 11...
# [2019-11-13 12:34:30] Bias-correcting 1 members separately...
# [2019-11-13 12:34:30] Done.
# Validation 27, 11 remaining
# [2019-11-13 12:34:31] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:35] Number of windows considered: 11...
# [2019-11-13 12:34:35] Bias-correcting 1 members separately...
# [2019-11-13 12:34:35] Done.
# Validation 28, 10 remaining
# [2019-11-13 12:34:37] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:41] Number of windows considered: 11...
# [2019-11-13 12:34:41] Bias-correcting 1 members separately...
# [2019-11-13 12:34:41] Done.
# Validation 29, 9 remaining
# [2019-11-13 12:34:43] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:47] Number of windows considered: 11...
# [2019-11-13 12:34:47] Bias-correcting 1 members separately...
# [2019-11-13 12:34:47] Done.
# Validation 30, 8 remaining
# [2019-11-13 12:34:49] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:53] Number of windows considered: 11...
# [2019-11-13 12:34:53] Bias-correcting 1 members separately...
# [2019-11-13 12:34:53] Done.
# Validation 31, 7 remaining
# [2019-11-13 12:34:54] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:34:58] Number of windows considered: 11...
# [2019-11-13 12:34:58] Bias-correcting 1 members separately...
# [2019-11-13 12:34:58] Done.
# Validation 32, 6 remaining
# [2019-11-13 12:35:00] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:04] Number of windows considered: 11...
# [2019-11-13 12:35:04] Bias-correcting 1 members separately...
# [2019-11-13 12:35:04] Done.
# Validation 33, 5 remaining
# [2019-11-13 12:35:05] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:09] Number of windows considered: 11...
# [2019-11-13 12:35:09] Bias-correcting 1 members separately...
# [2019-11-13 12:35:09] Done.
# Validation 34, 4 remaining
# [2019-11-13 12:35:11] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:15] Number of windows considered: 11...
# [2019-11-13 12:35:15] Bias-correcting 1 members separately...
# [2019-11-13 12:35:15] Done.
# Validation 35, 3 remaining
# [2019-11-13 12:35:16] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:20] Number of windows considered: 11...
# [2019-11-13 12:35:20] Bias-correcting 1 members separately...
# [2019-11-13 12:35:21] Done.
# Validation 36, 2 remaining
# [2019-11-13 12:35:22] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:26] Number of windows considered: 11...
# [2019-11-13 12:35:26] Bias-correcting 1 members separately...
# [2019-11-13 12:35:26] Done.
# Validation 37, 1 remaining
# [2019-11-13 12:35:28] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:32] Number of windows considered: 11...
# [2019-11-13 12:35:32] Bias-correcting 1 members separately...
# [2019-11-13 12:35:32] Done.
# Validation 38, 0 remaining
# [2019-11-13 12:35:34] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = yy, x = xx, newdata = newdata2, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:38] Number of windows considered: 11...
# [2019-11-13 12:35:38] Bias-correcting 1 members separately...
# [2019-11-13 12:35:38] Done.
# [1] "uas"
# [2019-11-13 12:35:41] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:45] Number of windows considered: 11...
# [2019-11-13 12:35:45] Bias-correcting 1 members separately...
# [2019-11-13 12:35:46] Done.
# [1] "vas"
# [2019-11-13 12:35:48] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:35:53] Number of windows considered: 11...
# [2019-11-13 12:35:53] Bias-correcting 1 members separately...
# [2019-11-13 12:35:54] Done.
# [1] "ps"
# [2019-11-13 12:35:56] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:36:00] Number of windows considered: 11...
# [2019-11-13 12:36:00] Bias-correcting 1 members separately...
# [2019-11-13 12:36:01] Done.
# [1] "tas"
# [2019-11-13 12:36:05] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:36:09] Number of windows considered: 11...
# [2019-11-13 12:36:09] Bias-correcting 1 members separately...
# [2019-11-13 12:36:10] Done.
# [1] "pr"
# [2019-11-13 12:36:12] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:36:16] Number of windows considered: 11...
# [2019-11-13 12:36:16] Bias-correcting 1 members separately...
# [2019-11-13 12:36:17] Done.
# [1] "rsds"
# [2019-11-13 12:36:20] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:36:24] Number of windows considered: 11...
# [2019-11-13 12:36:24] Bias-correcting 1 members separately...
# [2019-11-13 12:36:25] Done.
# [1] "rlds"
# [2019-11-13 12:36:28] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:36:32] Number of windows considered: 11...
# [2019-11-13 12:36:32] Bias-correcting 1 members separately...
# [2019-11-13 12:36:33] Done.
# [1] "hurs"
# [2019-11-13 12:36:36] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:36:41] Number of windows considered: 11...
# [2019-11-13 12:36:41] Bias-correcting 1 members separately...
# [2019-11-13 12:36:42] Done.
# [1] "cc"
# [2019-11-13 12:36:44] Argument precipitation is set as FALSE, please ensure that this matches your data.
# Warning message in biasCorrectionXD(y = y, x = x, newdata = newdata, precipitation = precipitation, :
# “There is only one member, argument join.members ignored.”[2019-11-13 12:36:48] Number of windows considered: 11...
# [2019-11-13 12:36:48] Bias-correcting 1 members separately...
# [2019-11-13 12:36:49] Done.
